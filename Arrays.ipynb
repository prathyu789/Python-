# %% [markdown]
# # <b> Arrays
# ## *array type*
# ![image.png](attachment:a4e049b8-608c-43f8-9e17-1ac9e983d31a.png)

# %%
import array as arr

# %%
vals = arr.array('i',[2 ,5 ,6 ,7 ,-9])

# %%
print (vals)
# Out:
# array('i', [2, 5, 6, 7, -9])
